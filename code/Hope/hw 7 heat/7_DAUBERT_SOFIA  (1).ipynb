# %% [markdown]
# # HOMEWORK 7 EPS 109
# ## stationary state of 2D Heat Equation

# %% [markdown]
# ### Part I- Finding Minima and Maxima by Hand
#
# Use the Numpy package to fill a vector x with 1000 random numbers between 0 and 1. Then
# proceed without using any predefined functions or libraries and determine the value and the index
# of the smallest elements of this vector
#
# This homework set is very much based on the 2D calculation in this week’s computer lab but we
# want to start from different initial conditions. The figure above shows the letter “O”. Write some
# Python code that approximately represent the second letter of your first name in capitalized form
# and use it as initial condition for the 2D heat equation with the following boundary conditions
#
# ### sOfia so im doing an O as well

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib tk

# %% [markdown]
# (1) Always keep that temperature fixed at 0 at the four boundaries. Repeatedly apply the update
# formula (**) form the lab assignment to find the stationary state in 2D. Write an .mp4 animation
# file in reasonably good resolution and submit it along with your notebook

# %%
#animation for 2D 
N = 100
padding = 10
padding2 = 20
grid = np.zeros((N + 1, N + 1))

initialH = 100
center = N // 2  # Center of the circle

for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding)**2:
            grid[i, j] = initialH
            
for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding2)**2:
            grid[i, j] = 0


plt.imshow(grid, cmap='viridis', origin='lower')
plt.colorbar()
plt.show()

# %%
#first circle 
import numpy as np
import matplotlib.pyplot as plt

N = 100
padding = 10
padding2 = 20
grid = np.zeros((N + 1, N + 1))

initialH = 100
center = N // 2  # Center of the circle

for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding)**2:
            grid[i, j] = initialH
            
for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding2)**2:
            grid[i, j] = 0


plt.imshow(grid, cmap='viridis', origin='lower')
plt.colorbar()
plt.show()

# %%
#new 
x = np.random.rand(1000)
minIndex = 0
minValue = x[minIndex]


#proceed without using any predefined functions or libraries and determine the value and the index of the smallest elements of this vector 
for i in range(len(x)):
    if x[i] < minValue:
        minIndex = i
        minValue = x[minIndex]
print(f"Minimum value {minValue} at index, {minIndex}.")


#write some python code that approx second letter of first name sOfia 
#use it as initial condition for the 2D heat equation 
#with the following boundary conditions 
N = 100
padding = 10
padding2 = 20
grid = np.zeros((N + 1, N + 1))

initialH = 100
center = N // 2  # Center of the circle

for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding)**2:
            grid[i, j] = initialH
            
for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding2)**2:
            grid[i, j] = 0
plt.imshow(grid)
L = 1.0
dx = L / (N - 1)

iterations = 100

X, Y = np.meshgrid(np.linspace(0, L, N + 1), np.linspace(0, L, N + 1))

fig = plt.figure()
# Out:
# Minimum value 0.0002407933980570487 at index, 98.

# %%
#old
x = np.random.rand(1000)
minIndex = 0
minValue = x[minIndex]


#proceed without using any predefined functions or libraries and determine the value and the index of the smallest elements of this vector 
for i in range(len(x)):
    if x[i] < minValue:
        minIndex = i
        minValue = x[minIndex]
print(f"Minimum value {minValue} at index, {minIndex}.")


#write some python code that approx second letter of first name sOfia 
#use it as initial condition for the 2D heat equation 
#with the following boundary conditions 
N = 100
padding = 10
grid = np.zeros((N + 1, N + 1))


initialH = 100
center = N // 2  # Center of the circle

for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding)**2:
            grid[i, j] = initialH
            
for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding2)**2:
            grid[i, j] = 0
# plt.imshow(grid)
L = 1.0
dx = L / (N - 1)

iterations = 100

X, Y = np.meshgrid(np.linspace(0, L, N + 1), np.linspace(0, L, N + 1))

fig = plt.figure()


#3d one 
#SAVE THIS 
for iteration in range(iterations):
    newGrid = np.copy(grid)
   
    for i in range(1, N):
        for j in range(1, N):
            newGrid[i, j] = 0.25 * (grid[i, j + 1] + grid[i, j - 1] + grid[i - 1, j] + grid[i + 1, j])
 
        newGrid[0, :] = 0
        newGrid[N, :] = 0
        newGrid[:, 0] = 0
        newGrid[:, N] = 0
    
    grid = newGrid
    fig.clear() #why am i having problems with this 
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, grid, cmap=cm.plasma, antialiased=False)
    ax.set_zlim3d(0, 100)
    plt.title(f'Iteration {iteration}')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.pause(0.01)

plt.show()
# Out:
# Minimum value 0.002709944427022437 at index, 675.

# %% [markdown]
# ## Next part of problem
# #### other boundaries and corners

# %%
N = 100
padding = 10
grid = np.zeros((N + 1, N + 1))

initialH = 100
center = N // 2  # Center of the circle

for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding)**2:
            grid[i, j] = initialH
            
for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding2)**2:
            grid[i, j] = 0

L = 1.0
dx = L / (N - 1)

iterations = 100

X, Y = np.meshgrid(np.linspace(0, L, N + 1), np.linspace(0, L, N + 1))

fig = plt.figure()



for iteration in range(iterations):
    newGrid = np.copy(grid)
   
    for i in range(1, N):
        for j in range(1, N):
            newGrid[i, j] = 0.25 * (grid[i, j + 1] + grid[i, j - 1] + grid[i - 1, j] + grid[i + 1, j])

        newGrid[0, :] = 0
        newGrid[N, :] = 0
        newGrid[:, 0] = 0
        newGrid[:, N] = 0
    
    grid = newGrid
    fig.clear()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, grid, cmap=cm.coolwarm, antialiased=False)
    plt.title(f'Iteration {iteration}')
    plt.xlabel('X')
    ax.set_zlim3d(0, 100)
    plt.ylabel('Y')
    plt.pause(0.01)

    plt.show()

# %%
N = 100
padding = 10
grid = np.zeros((N + 1, N + 1))

initialH = 100
center = N // 2  # Center of the circle

for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding)**2:
            grid[i, j] = initialH
            
for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding2)**2:
            grid[i, j] = 0

L = 1.0
dx = L / (N - 1)

iterations = 1000

X, Y = np.meshgrid(np.linspace(0, L, N + 1), np.linspace(0, L, N + 1))

fig = plt.figure()

for iteration in range(iterations):
    newGrid = np.copy(grid)

    for i in range(1, N):
        for j in range(1, N):
            newGrid[i, j] = 0.25 * (grid[i, j + 1] + grid[i, j - 1] + grid[i - 1, j] + grid[i + 1, j])

            
            
    for i in range(1, N):
        newGrid[i, 0] = (grid[i, 0] + grid[i + 1, 0] + grid[i - 1, 0] + grid[i, 1]) / 4.0
        newGrid[i, N] = (grid[i, N] + grid[i + 1, N] + grid[i - 1, N] + grid[i, N - 1]) / 4.0

    for j in range(1, N):
        newGrid[0, j] = (grid[0, j] + grid[0, j + 1] + grid[0, j - 1] + grid[1, j]) / 4.0
        newGrid[N, j] = (grid[N, j] + grid[N, j + 1] + grid[N, j - 1] + grid[N - 1, j]) / 4.0

    newGrid[0, 0] = (2.0 * grid[0, 0] + grid[1, 0] + grid[0, 1]) / 4.0 #from assignment 
    newGrid[N, 0] = (2.0 * grid[N, 0] + grid[N - 1, 0] + grid[N, 1]) / 4.0
    newGrid[0, N] = (2.0 * grid[0, N] + grid[1, N] + grid[0, N - 1]) / 4.0
    newGrid[N, N] = (2.0 * grid[N, N] + grid[N - 1, N] + grid[N, N - 1]) / 4.0






    grid = newGrid
    fig.clear()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, grid, cmap=cm.coolwarm, antialiased=False)
    plt.title(f'Iteration {iteration}')
    ax.set_zlim3d(0, 100)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.pause(0.05)

plt.show()

# %% [markdown]
# ### Last part

# %%
#new one with my code 
# %matplotlib tk

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

N = 100
padding = 10
padding2 = 20
grid = np.zeros((N + 1, N + 1))

initialH = 100
center = N // 2  # Center of the circle

for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding)**2:
            grid[i, j] = initialH
            
for i in range(N + 1):
    for j in range(N + 1):
        # Check if the point (i, j) is inside the circle
        if (i - center)**2 + (j - center)**2 <= (N / 2 - padding2)**2:
            grid[i, j] = 0

L = 1.0
dx = L / (N - 1)

X, Y = np.meshgrid(np.linspace(0, L, N + 1), np.linspace(0, L, N + 1))

fig = plt.figure()
L = 1.0
dx = L / (N - 1)

iterations = 333

X, Y = np.meshgrid(np.linspace(0, L, N + 1), np.linspace(0, L, N + 1))

from matplotlib.animation import FFMpegWriter
metadata = dict(title='My first animation in 3d', artist='sofia daubert',comment='part 2 testing.')
writer = FFMpegWriter(fps=15, metadata=metadata)
fig = plt.figure()

with writer.saving(fig, "part22.mp4", dpi=200):
    for iteration in range(iterations):
        print(np.sum(grid))
        newGrid = np.copy(grid)

        for i in range(1, N):
            for j in range(1, N):
                newGrid[i, j] = 0.25 * (grid[i, j + 1] + grid[i, j - 1] + grid[i - 1, j] + grid[i + 1, j])

                
                
        for i in range(1, N):
            newGrid[i, 0] = (grid[i, 0] + grid[i + 1, 0] + grid[i - 1, 0] + grid[i, 1]) / 4.0
            newGrid[i, N] = (grid[i, N] + grid[i + 1, N] + grid[i - 1, N] + grid[i, N - 1]) / 4.0

        for j in range(1, N):
            newGrid[0, j] = (grid[0, j] + grid[0, j + 1] + grid[0, j - 1] + grid[1, j]) / 4.0
            newGrid[N, j] = (grid[N, j] + grid[N, j + 1] + grid[N, j - 1] + grid[N - 1, j]) / 4.0

        newGrid[0, 0] = (2.0 * grid[0, 0] + grid[1, 0] + grid[0, 1]) / 4.0
        newGrid[N, 0] = (2.0 * grid[N, 0] + grid[N - 1, 0] + grid[N, 1]) / 4.0
        newGrid[0, N] = (2.0 * grid[0, N] + grid[1, N] + grid[0, N - 1]) / 4.0
        newGrid[N, N] = (2.0 * grid[N, N] + grid[N - 1, N] + grid[N, N - 1]) / 4.0

        grid = newGrid
        fig.clear()
        ax = fig.add_subplot(111, projection='3d')
        ax.plot_surface(X, Y, grid, cmap=cm.coolwarm, antialiased=False)
        plt.title(f'Iteration {iteration}')
        plt.xlabel('X')
        ax.set_zlim3d(0, 100)
        plt.ylabel('Y')
        plt.pause(0.1)
        plt.show()
        writer.grab_frame()
