B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec206_L101_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec207_L65_B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec209_L83_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec210_L60_B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec211_L92_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec212_L106_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec213_L78_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec214_L111_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec215_L74_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec216_L115_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec217_L88_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec218_L69_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec219_L97_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec220_L65_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec221_L60_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec222_L83_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec223_L101_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec224_L78_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec225_L92_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec226_L74_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec227_L69_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec228_L65_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec229_L60_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec230_L88_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec231_L106_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec232_L97_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec233_L83_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec234_L78_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec235_L74_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec236_L60_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec237_L69_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec238_L65_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec239_L92_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec240_L111_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec241_L101_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec242_L88_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec243_L83_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec244_L60_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec245_L78_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec246_L65_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec247_L74_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec248_L69_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec249_L97_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec250_L92_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec251_L106_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec252_L60_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec253_L88_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec254_L65_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec255_L83_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec256_L69_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec257_L78_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec258_L74_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec259_L115_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec260_L101_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec261_L60_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec262_L65_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec263_L97_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec264_L69_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec265_L92_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec266_L74_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec267_L78_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec268_L88_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec269_L83_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec270_L60_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec271_L111_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec272_L65_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec273_L69_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec274_L74_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec275_L106_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec276_L78_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec277_L60_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec278_L83_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec279_L101_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec280_L88_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec281_L65_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec282_L92_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec283_L97_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec284_L69_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec285_L74_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec286_L60_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec287_L78_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec288_L65_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec289_L83_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec290_L69_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec291_L88_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec292_L60_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec293_L74_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec294_L92_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec295_L65_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec296_L97_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec297_L78_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec298_L101_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec299_L69_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec300_L83_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec301_L106_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec302_L74_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec303_L88_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec304_L111_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec305_L78_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec306_L92_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec307_L115_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec308_L83_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec309_L97_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec310_L88_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec312_L101_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec313_L92_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec314_L106_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec315_L97_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec316_L101_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec317_L111_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec318_L106_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec319_L115_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec320_L111_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec321_L115_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec322_L120_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec323_L120_B20.npz']

# %%
# noise files
noises = glob.glob('/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra/*.npz')

# gain files with noise
gain0_spec = np.load('/Users/rrrod/FFC_4/data/obs_042424/Phase1/spec3_L134_B20.npz')
gain0_noise = np.load('/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra/NoiseSpec3_L134_B20.npz')
gain1_spec = np.load('/Users/rrrod/FFC_4/data/obs_042424/Phase2/spec167_L115_B47.npz')
gain1_noise = np.load('/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra/NoiseSpec167_L115_B47.npz')
gain1_spec = np.load('/Users/rrrod/FFC_4/data/obs_042424/Phase2/spec320_L111_B20.npz')
gain2_noise = np.load('/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra/NoiseSpec320_L111_B20.npz')

# %%
''' 
    sort files by the original "galactic index" 
    which ordered the coordinates in galactic
'''
leusch_data = sorted(files, key=lambda x: np.load(x)['coords'][5])

# %%
noise_len = len(noises)
print('Number of noise files imported:', noise_len) # confirms all files are loaded
print()
noises # lists all files loaded
# Out:
# Number of noise files imported: 9
# ['/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec164_L115_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec165_L111_B57.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec167_L115_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec319_L115_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec320_L111_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec321_L115_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec322_L120_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec323_L120_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Noise_Spectra\\NoiseSpec3_L134_B20.npz']

# %%
len_testdata = len(leusch_data)
print('Number of noise files imported:', len_testdata) # confirms all files are loaded
print()
leusch_data # lists all files loaded
# Out:
# Number of noise files imported: 292
# ['/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec292_L60_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec286_L60_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec277_L60_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec270_L60_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec261_L60_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec252_L60_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec244_L60_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec236_L60_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec229_L60_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec221_L60_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec210_L60_B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec200_L60_B57.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec295_L65_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec288_L65_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec281_L65_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\spec272_L65_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase2\\sp
B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec33_L161_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec42_L161_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec49_L161_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec63_L161_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec73_L161_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec82_L161_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec92_L161_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec101_L161_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec112_L161_B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec121_L161_B57.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec18_L166_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec26_L166_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec35_L166_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec44_L166_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec51_L166_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec60_L166_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec72_L166_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec80_L166_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec89_L166_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec98_L166_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec109_L166_B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec117_L166_B57.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec21_L170_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec29_L170_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec36_L170_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec45_L170_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec53_L170_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec59_L170_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec69_L170_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec79_L170_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec88_L170_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec96_L170_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec105_L170_B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec115_L170_B57.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec24_L175_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec32_L175_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec37_L175_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec47_L175_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec54_L175_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec61_L175_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec67_L175_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec77_L175_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec86_L175_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec94_L175_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec102_L175_B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec113_L175_B57.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec28_L180_B20.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec34_L180_B23.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec38_L180_B27.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec48_L180_B30.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec56_L180_B34.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec62_L180_B37.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec68_L180_B40.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec76_L180_B44.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec84_L180_B47.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec93_L180_B51.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec100_L180_B54.npz',
#  '/Users/rrrod/FFC_4/data/obs_042424/Phase1\\spec111_L180_B57.npz']

# %%
# make length object, empty arrays
len_testdata = len(leusch_data) 
pwr0 = [] 
pwr1 = []
unix = []
coordinates = []
alt_az = []
jd = []
galactic = []

# iterate through all 'testdata' object 
# grab info as well 
for n in range(len_testdata):
    test_dataFiles = np.load(leusch_data[n])
    # spectra 
    pwr0.append(test_dataFiles["data0"]) # Append data
    pwr1.append(test_dataFiles["data1"])
    unix.append(test_dataFiles['time'][()])
    coordinates.append(test_dataFiles['coords'])
    galactic.append([test_dataFiles['coords'][1], test_dataFiles['coords'][2]])
    jd.append(test_dataFiles['jd'])

# %%
# shifting
for i in range(len(pwr0)): 
    pwr0[i] = np.fft.fftshift(pwr0[i])

for i in range(len(pwr1)):
    pwr1[i] = np.fft.fftshift(pwr1[i])

# frequency
freqs = 1420 + np.fft.fftshift(np.fft.fftfreq(len(pwr0[i]), 1/3.2))

# %%
# plotting that shit
plt.figure(figsize=(12, 6))
plt.semilogy(pwr0[10])
plt.title(f'pwr0_{i}')
plt.show()

# %%
# defining some stuff
model = savgol_filter(pwr0[10], 499, 3) # fitting a model
pwr010_pos = pwr0[10][1050:1900] # observation data
model_pos = savgol_filter(pwr010_pos, 500, 3) # model

# plotting!
plt.figure(figsize=(12, 6))
plt.semilogy(freqs[1050:1900], pwr010_pos, label='Data', color='royalblue') # observation data
plt.semilogy(freqs[1050:1900], model_pos, label='Model', color='firebrick') # model
plt.title('Power vs Frequency', fontsize=20) # gives it a sick title
plt.xlabel(r'Frequency [$\nu$]', fontsize=18)
plt.ylabel(r'Power [arbitrary]', fontsize=18)
plt.legend()
plt.show()

# %%
divided = pwr010_pos/model_pos # another defined variable

# plotting!
plt.figure(figsize=(12, 6))
plt.plot(divided, label='Data', color='royalblue') # observation data
plt.title('Power of Observation Divided by Power of Model', fontsize=20) # gives it a sick title
plt.show()

# %%
# variables to take half of set and flip it
switch_set = pwr0[10][0:1025]
switch_index = np.arange(0, 1025, 1)
switched = np.flip(switch_set)

# plotting
plt.figure(figsize=(12, 6))
plt.semilogy(switched, label='Data', color='royalblue') # observation data
plt.title('Power of Observation Divided by Power of Model', fontsize=20) # gives it a sick title
plt.show()

# %%
# flattens the data
pwr0_flat = pwr0[10][1023:2048]/switched

# plotting
plt.figure(figsize=(12, 6))
plt.semilogy(pwr0_flat, label='Data', color='royalblue') # observation data
plt.ylim(5e-2, 0.5e1)
plt.title('Flattened Data', fontsize=20) # gives it a sick title
plt.show()

# %%
# flatten... again?
new_flat = pwr0[10].flatten()

# plotting
plt.figure(figsize=(12, 6))
plt.semilogy(new_flat, color='seagreen')
plt.xlim(1000, 1600)
plt.ylim(1e4, 1e6)
plt.title('Flattened Data', fontsize=20) # gives it a sick title
plt.show()

# %%
# flattens the index
flatter = np.arange(1023, 2048, 1)
print('Length of flattened index:', len(flatter))
# Out:
# Length of flattened index: 1025

# %%
divided0 = [] 
chunked0 = []
for i in range(len(pwr0)):
    spectra = pwr0[i]
    switch_set = spectra[0:1024] 
    switched = np.flip(switch_set)
    flatter = spectra[1024:2048]/switched
    chunked = flatter[5:600]
    divided0.append(flatter)
    chunked0.append(chunked)

divided1 = []
chunked1 = []
for i in range(len(pwr1)):
    spectra = pwr1[i]
    switch_set = spectra[0:1024] 
    switched = np.flip(switch_set)
    flatter = spectra[1024:2048]/switched
    chunked = flatter[50:600]
    divided1.append(flatter)
    chunked1.append(chunked)
    
d0 = len(divided0[0])
c0 = len(chunked0[0])
d1 = len(divided1[0])
c1 = len(chunked1[0])

print('Length of divided0, chunked0, divided1, and chunked1:', d0,'|', c0, '|', d1, '|', c1, 'in that order.')
# Out:
# Length of divided0, chunked0, divided1, and chunked1: 1024 | 595 | 1024 | 550 in that order.

# %%
# plotting
plt.figure(figsize=(12, 6))
plt.semilogy(chunked0[30], color='slateblue')
plt.title("Chunk o' Data", fontsize=20) # gives it a sick title
plt.show()

# %%
the300 = np.load('/Users/rrrod/FFC_4/data/obs_042424/Phase2/spec323_L120_B20.npz', allow_pickle=True)

print(the300['missed'])
# Out:
# {1: [51.53828711063656, 1.1991023186681529], 2: [62.08904253931914, 4.403520617876413], 4: [48.172171767721366, 1.8413168937712994], 12: [44.8338517354441, 2.2868666723494537], 46: [41.678166935480085, 2.452720593232178], 149: [39.13757190290301, 3.1899928026737085]}

# %%
table
# Out:
#      Unnamed: 0      L     B          RA        DEC  Galactic_Index
# 0             0  124.4  20.0   23.851192  82.746098             168
# 1             1  124.4  23.4   32.778248  86.042542             169
# 2             2  129.0  20.0   52.084066  80.962227             180
# 3             3  133.6  20.0   69.006710  77.908980             192
# 4             4  129.0  23.4   69.993942  83.367395             181
# ..          ...    ...   ...         ...        ...             ...
# 319         319  115.2  23.4  309.232324  82.078465             145
# 320         320  110.6  20.0  312.501293  76.649154             132
# 321         321  115.2  20.0  326.412516  79.953801             144
# 322         322  119.8  23.4  334.954938  85.318438             157
# 323         323  119.8  20.0  350.278198  82.316496             156
#
# [324 rows x 6 columns]

# %%
len_gal = len(galactic)
print('Number of noise files imported:', len_gal) # confirms all files are loaded
print()
galactic # lists all files loaded
# Out:
# Number of noise files imported: 292
# [[60.0, 20.0],
#  [60.0, 23.4],
#  [60.0, 26.8],
#  [60.0, 30.2],
#  [60.0, 33.599999999999994],
#  [60.0, 36.99999999999999],
#  [60.0, 40.39999999999999],
#  [60.0, 43.79999999999999],
#  [60.0, 47.19999999999999],
#  [165.79999999999987, 26.8],
#  [165.79999999999987, 30.2],
#  [165.79999999999987, 33.599999999999994],
#  [165.79999999999987, 36.99999999999999],
#  [165.79999999999987, 40.39999999999999],
#  [165.79999999999987, 43.79999999999999],
#  [165.79999999999987, 47.19999999999999],
#  [165.79999999999987, 50.59999999999999],
#  [165.79999999999987, 53.99999999999999],
#  [165.79999999999987, 57.399999999999984],
#  [170.39999999999986, 20.0],
#  [170.39999999999986, 23.4],
#  [170.39999999999986, 26.8],
#  [170.39999999999986, 30.2],
#  [170.39999999999986, 33.599999999999994],
#  [170.39999999999986, 36.99999999999999],
#  [170.39999999999986, 40.39999999999999],
#  [170.39999999999986, 43.79999999999999],
#  [170.39999999999986, 47.19999999999999],
#  [170.39999999999986, 50.59999999999999],
#  [170.39999999999986, 53.99999999999999],
#  [170.39999999999986, 57.399999999999984],
#  [174.99999999999986, 20.0],
#  [174.99999999999986, 23.4],
#  [174.99999999999986, 26.8],
#  [174.99999999999986, 30.2],
#  [174.99999999999986, 33.599999999999994],
#  [174.99999999999986, 36.99999999999999],
#  [174.99999999999986, 40.39999999999999],
#  [174.99999999999986, 43.79999999999999],
#  [174.99999999999986, 47.19999999999999],
#  [174.99999999999986, 50.59999999999999],
#  [174.99999999999986, 53.99999999999999],
#  [174.99999999999986, 57.399999999999984],
#  [179.59999999999985, 20.0],
#  [179.59999999999985, 23.4],
#  [179.59999999999985, 26.8],
#  [179.59999999999985, 30.2],
#  [179.59999999999985, 33.599999999999994],
#  [179.59999999999985, 36.99999999999999],
#  [179.59999999999985, 40.39999999999999],
#  [179.59999999999985, 43.79999999999999],
#  [179.59999999999985, 47.19999999999999],
#  [179.59999999999985, 50.59999999999999],
#  [179.59999999999985, 53.99999999999999],
#  [179.59999999999985, 57.399999999999984]]

# %%
'''
“In the middle of the journey of our life I found myself 
within a dark woods where the straight way was lost.”
                                    - Dante's Inferno
'''
plt.figure(figsize = (10, 7))
for i in range(len(pwr0)):
    plt.semilogy(freqs, pwr0[i])
plt.title('Power vs Frequency (for all pwr0 sets)')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Power [Arbitrary]')
plt.show()

# %%
''' 
"Leave all hope, ye who enter here!"
                - Dante's Inferno
'''
plt.figure(figsize = (10, 7))
for i in range(len(pwr1)):
    plt.semilogy(freqs, pwr1[i])
plt.title('Power vs Frequency (for all pwr1 sets)')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Power [Arbitrary]')
plt.show()

# %%
''' 
"Thence we came forth to rebehold the stars."
                        - Dante's Inferno
'''
plt.figure(figsize = (12, 6))
for i in range(len(pwr0)):
    plt.semilogy(freqs, pwr0[i])
plt.title('Power vs Frequency (for all pwr0 sets - zoomed in)')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Power [Arbitrary]')
plt.xlim(1420.2, 1421)
plt.ylim(1.5e4, 4e5)
plt.show()

# %%
freqs2 = freqs[1000:1500]

plt.figure(figsize = (12, 6))
plt.semilogy(freqs2, pwr0[0][1000:1500], color='royalblue')
plt.title("Power vs Frequency (flattened n' shit)", fontsize=20)
plt.xlabel('Frequency [Hz]', fontsize=18)
plt.ylabel('Power [Arbitrary]', fontsize=18)
plt.show()

# %% [markdown]
# # Beyond here is some bullshit

# %%
# Extracting galactic coordinates
galactic_longitudes = [coord[0] for coord in galactic]
galactic_latitudes = [coord[1] for coord in galactic]

# Plotting the map projection
plt.figure(figsize=(10, 6))
plt.scatter(galactic_longitudes, galactic_latitudes, c='royalblue', marker='o', alpha=0.8)
plt.xlabel('Galactic Longitude')
plt.ylabel('Galactic Latitude')
plt.title('Map Projection of Data')
plt.grid(True)
plt.show()

# %%
data = np.array(galactic)

# plots the map projection
plt.figure(figsize=(10, 6))
plt.imshow(data, extent=[min(galactic_longitudes), max(galactic_longitudes), min(galactic_latitudes), max(galactic_latitudes)], aspect='auto', cmap='nipy_spectral')
plt.colorbar(label='Intensity')
plt.xlabel('Galactic Longitude')
plt.ylabel('Galactic Latitude')
plt.title('Map Projection of Data')
plt.grid(False)
plt.show()

# %%
# Assuming you have longitude and latitude arrays
NLON, NLAT = len(galactic[0]), len(galactic)  # Number of pixels in longitude and latitude
xs, ys = np.indices((NLAT, NLON))  # Get the array indices for each pixel
lats = (xs - NLAT/2) * 180 / NLAT  # Scale [0:NLAT) to [-90:90)
lons = (ys - NLON/2) * 360 / NLON  # Scale [0:NLON) to [-180:180)

# Replace this with your actual data
data_longitude = np.array(galactic)
data_latitude = np.array(galactic)

# Create Cartopy projections
projection = ccrs.PlateCarree()

# Create a new figure and axis for each plot
plt.figure(figsize=(12, 6))

# Plot cylindrical projection (longitude)
ax1 = plt.subplot(1, 2, 1, projection=projection)
ax1.set_title('Cylindrical Projection (Longitude)')
img_longitude = ax1.imshow(data_longitude, extent=(-180, 180, -90, 90), transform=ccrs.PlateCarree(), cmap='viridis')
ax1.set_xlabel('Longitude')
ax1.set_ylabel('Latitude')
ax1.set_xticks([-180, -120, -60, 0, 60, 120, 180], crs=ccrs.PlateCarree())
ax1.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())
ax1.xaxis.set_major_formatter(LONGITUDE_FORMATTER)
ax1.yaxis.set_major_formatter(LATITUDE_FORMATTER)
ax1.grid()

# Plot cylindrical projection (latitude)
ax2 = plt.subplot(1, 2, 2, projection=projection)
ax2.set_title('Cylindrical Projection (Latitude)')
img_latitude = ax2.imshow(data_latitude, extent=(-180, 180, -90, 90), transform=ccrs.PlateCarree(), cmap='viridis')
ax2.set_xlabel('Longitude')
ax2.set_ylabel('Latitude')
ax2.set_xticks([-180, -120, -60, 0, 60, 120, 180], crs=ccrs.PlateCarree())
ax2.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())
ax2.xaxis.set_major_formatter(LONGITUDE_FORMATTER)
ax2.yaxis.set_major_formatter(LATITUDE_FORMATTER)
ax2.grid(False)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np

# Assuming you have longitude and latitude arrays
NLON, NLAT = len(galactic[0]), len(galactic)  # Number of pixels in longitude and latitude
xs, ys = np.indices((NLAT, NLON))  # Get the array indices for each pixel
lats = (xs - NLAT/2) * 180 / NLAT  # Scale [0:NLAT) to [-90:90)
lons = (ys - NLON/2) * 360 / NLON  # Scale [0:NLON) to [-180:180)

# Replace this with your actual data
data_longitude = np.array(galactic)
data_latitude = np.array(galactic)

# Create Cartopy projections
projection = ccrs.PlateCarree()

# Create a new figure and axis for each plot
plt.figure(figsize=(18, 9))

# Plot cylindrical projection (longitude)
ax1 = plt.subplot(2, 2, 1, projection=projection)
ax1.set_title('Cylindrical Projection (Longitude)')
img_longitude = ax1.imshow(data_longitude, extent=(-180, 180, -90, 90), transform=ccrs.PlateCarree(), cmap='viridis')
ax1.set_xlabel('Longitude')
ax1.set_ylabel('Latitude')
ax1.grid()

# Plot cylindrical projection (latitude)
ax2 = plt.subplot(2, 2, 2, projection=projection)
ax2.set_title('Cylindrical Projection (Latitude)')
img_latitude = ax2.imshow(data_latitude, extent=(-180, 180, -90, 90), transform=ccrs.PlateCarree(), cmap='viridis')
ax2.set_xlabel('Longitude')
ax2.set_ylabel('Latitude')
ax2.grid(False)

# Plot additional projections
projections = [ccrs.Mollweide(), ccrs.Mercator()]

for i, proj in enumerate(projections, start=3):
    ax = plt.subplot(2, 2, i, projection=proj)
    ax.set_title(f'Projection {i-2}')
    ax.imshow(data_longitude, extent=(-180, 180, -90, 90), transform=ccrs.PlateCarree(), cmap='viridis')
    ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linestyle='--')

plt.tight_layout()
plt.show()

# %%
# Assuming you have longitude and latitude arrays
NLON, NLAT = len(galactic[0]), len(galactic)  # Number of pixels in longitude and latitude
xs, ys = np.indices((NLAT, NLON))  # Get the array indices for each pixel
lats = (xs - NLAT/2) * 180 / NLAT  # Scale [0:NLAT) to [-90:90)
lons = (ys - NLON/2) * 360 / NLON  # Scale [0:NLON) to [-180:180)

# Replace this with your actual data
data_longitude = np.array(galactic)
data_latitude = np.array(galactic)

# Create Cartopy projections
projection = ccrs.Orthographic(central_latitude=90)
data_crs = ccrs.PlateCarree()

# Create a new figure and axis for each plot
fig, axes = plt.subplots(ncols=2, figsize=(14, 6), subplot_kw={'projection': projection})

# Plot orthographic projection (longitude)
axes[0].set_title('Orthographic Projection (Longitude)')
img_longitude = axes[0].imshow(data_longitude, extent=(-180, 180, -90, 90), transform=data_crs, cmap='viridis')
axes[0].gridlines(crs=data_crs, draw_labels=True, linestyle='--')

# Plot orthographic projection (latitude)
axes[1].set_title('Orthographic Projection (Latitude)')
img_latitude = axes[1].imshow(data_latitude, extent=(-180, 180, -90, 90), transform=data_crs, cmap='viridis')
axes[1].gridlines(crs=data_crs, draw_labels=True, linestyle='--')

plt.tight_layout()
plt.show()

# %%
# Assuming you have longitude and latitude arrays
NLON, NLAT = len(galactic[0]), len(galactic)  # Number of pixels in longitude and latitude
xs, ys = np.indices((NLAT, NLON))  # Get the array indices for each pixel
lats = (xs - NLAT/2) * 180 / NLAT  # Scale [0:NLAT) to [-90:90)
lons = (ys - NLON/2) * 360 / NLON  # Scale [0:NLON) to [-180:180)

# Replace this with your actual data
data_longitude = np.array(galactic)
data_latitude = np.array(galactic)

# Create Cartopy projection
projection = ccrs.Gnomonic(central_latitude=60, central_longitude=-30)

# Create a new figure and axis
fig = plt.figure(figsize=(6, 6))
ax = plt.axes(projection=projection)

# Plot the Gnomonic projection
ax.set_title('Gnomic Projection (Longitude)')

img = ax.imshow(data_longitude, extent=(-180, 180, -90, 90), transform=ccrs.PlateCarree(), cmap='nipy_spectral')

plt.colorbar(img, orientation='vertical', label='Intensity')

plt.show()
