# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
cd
# Out:
# /Users/leayamashiro

# %%
SDR0_1420_0 = np.load('FFC_4/data/testing_041624/testing_SDR0_0.npz')['data']
SDR1_1420_0 = np.load('FFC_4/data/testing_041624/testing_SDR1_0.npz')['data']

# %%
plt.semilogy(SDR0_1420_0)
plt.xlim(1000,1400)
# Out:
# (1000.0, 1400.0)

# %%
plt.plot(SDR0_1420_0)

# %%
len(SDR0_1420_0)
# Out:
# 2048

# %%
frequency_axis = np.fft.fftshift(np.fft.fftfreq(len(SDR0_1420_0), 1/3.2))
LO_1420 = 1420
LO_1420p8 = 1420.8
freqs_1420 = frequency_axis + LO_1420
freqs_1420p8 = frequency_axis + LO_1420p8

# %%
plt.semilogy(freqs_1420, SDR0_1420_0)
plt.title('Hydrogen Bumpin, SDR0')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Power [arb]')
plt.xlim(1420.1, 1421.2)
plt.ylim(10,10**6)
# Out:
# (10, 1000000)

# %%
plt.semilogy(freqs_1420, SDR1_1420_0)
plt.title('Hydrogen Bumpin, SDR1')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Power [arb]')
plt.xlim(1420.1, 1421.2)
plt.ylim(40,14**4)
# Out:
# (40, 38416)

# %% [markdown]
# ## NOTE: THIS WASN'T USING THE NOISE DIODE! (I just wanted to get a spectra, without noise, and that was one more step oops.) Hence, data is fucking noisy.
